-- %%
:l Hutton Syntax Parsing Interpreting Visualisation

import Syntax
import Interpreting
import Visualisation

import qualified Data.Map as Map

-- %%
b <- readFile "progs/root"

putStr b

b' = parseProgram b

run b' [36] def (renderProgram . (!! 25))

run b' (map (^2) [1,4]) def logP
-- Out:
-- @1
--    MOV 0 ACC
--    SUB IN
-- &: ADD @2
--    MOV -2 @2
--    JLZ &
--    MOV @2 @2
--    MOV ACC @2
--
-- @2
-- &: MOV ACC @1
--    SUB @1
--    JGZ &
--    MOV @1 OUT
-- ╔═══════════════════╦══════╗
-- ║MOV 0 ACC          ║ ACC  ║
-- ║SUB IN             ║  -16 ║
-- ║ADD @2             ╠══════╣
-- ║MOV -2 @2          ║ BAK  ║
-- ║JRO LZ -2          ║   (0)║
-- ║MOV @2 @2          ╠══════╣
-- ║MOV ACC @2         ║      ║
-- ║                   ║      ║
-- ║                   ║      ║
-- ║                   ║      ║
-- ║                   ║      ║
-- ║                   ║      ║
-- ║                   ║      ║
-- ║                   ║      ║
-- ║                   ║      ║
-- ╚═══════════════════╩══════╝
-- ╔═══════════════════╦══════╗
-- ║MOV ACC @1         ║ ACC  ║
-- ║SUB @1             ║   10 ║
-- ║JRO GZ -2          ╠══════╣
-- ║MOV @1 OUT         ║ BAK  ║
-- ║                   ║   (0)║
-- ║                   ╠══════╣
-- ║                   ║      ║
-- ║                   ║      ║
-- ║                   ║      ║
-- ║                   ║      ║
-- ║                   ║      ║
-- ║                   ║      ║
-- ║                   ║      ║
-- ║                   ║      ║
-- ║                   ║      ║
-- ╚═══════════════════╩══════╝
--  0: MOV 0 ACC   |   0| (   0)        0: MOV ACC @1  |   0| (   0)       [1,16][]
--  1: SUB IN      |   0| (   0)        0: Mov 0 @1    |   0| (   0)       [1,16][]
--  2: ADD @2      |  -1| (   0)        0: Mov 0 @1    |   0| (   0)       [16][]
--  3: MOV -2 @2   |  -1| (   0)        1: SUB @1      |   0| (   0)       [16][]
--  3: Mov -2 @2   |  -1| (   0)        1: SUB @1      |   0| (   0)       [16][]
--  4: JRO LZ -2   |  -1| (   0)        2: JRO GZ -2   |   2| (   0)       [16][]
--  2: ADD @2      |  -1| (   0)        0: MOV ACC @1  |   2| (   0)       [16][]
--  2: ADD @2      |  -1| (   0)        0: Mov 2 @1    |   2| (   0)       [16][]
--  3: MOV -2 @2   |   1| (   0)        1: SUB @1      |   2| (   0)       [16][]
--  3: Mov -2 @2   |   1| (   0)        1: SUB @1      |   2| (   0)       [16][]
--  4: JRO LZ -2   |   1| (   0)        2: JRO GZ -2   |   4| (   0)       [16][]
--  5: MOV @2 @2   |   1| (   0)        0: MOV ACC @1  |   4| (   0)       [16][]
--  5: MOV @2 @2   |   1| (   0)        0: Mov 4 @1    |   4| (   0)       [16][]
--  5: Mov 4 @2    |   1| (   0)        1: SUB @1      |   4| (   0)       [16][]
--  6: MOV ACC @2  |   1| (   0)        2: JRO GZ -2   |   0| (   0)       [16][]
--  6: Mov 1 @2    |   1| (   0)        3: MOV @1 OUT  |   0| (   0)       [16][]
--  0: MOV 0 ACC   |   1| (   0)        3: Mov 1 OUT   |   0| (   0)       [16][]
--  1: SUB IN      |   0| (   0)        0: MOV ACC @1  |   0| (   0)       [16][1]
--  2: ADD @2      | -16| (   0)        0: Mov 0 @1    |   0| (   0)       [][1]
--  3: MOV -2 @2   | -16| (   0)        1: SUB @1      |   0| (   0)       [][1]
--  3: Mov -2 @2   | -16| (   0)        1: SUB @1      |   0| (   0)       [][1]
--  4: JRO LZ -2   | -16| (   0)        2: JRO GZ -2   |   2| (   0)       [][1]
--  2: ADD @2      | -16| (   0)        0: MOV ACC @1  |   2| (   0)       [][1]
--  2: ADD @2      | -16| (   0)        0: Mov 2 @1    |   2| (   0)       [][1]
--  3: MOV -2 @2   | -14| (   0)        1: SUB @1      |   2| (   0)       [][1]
--  3: Mov -2 @2   | -14| (   0)        1: SUB @1      |   2| (   0)       [][1]
--  4: JRO LZ -2   | -14| (   0)        2: JRO GZ -2   |   4| (   0)       [][1]
--  2: ADD @2      | -14| (   0)        0: MOV ACC @1  |   4| (   0)       [][1]
--  2: ADD @2      | -14| (   0)        0: Mov 4 @1    |   4| (   0)       [][1]
--  3: MOV -2 @2   | -10| (   0)        1: SUB @1      |   4| (   0)       [][1]
--  3: Mov -2 @2   | -10| (   0)        1: SUB @1      |   4| (   0)       [][1]
--  4: JRO LZ -2   | -10| (   0)        2: JRO GZ -2   |   6| (   0)       [][1]
--  2: ADD @2      | -10| (   0)        0: MOV ACC @1  |   6| (   0)       [][1]
--  2: ADD @2      | -10| (   0)        0: Mov 6 @1    |   6| (   0)       [][1]
--  3: MOV -2 @2   |  -4| (   0)        1: SUB @1      |   6| (   0)       [][1]
--  3: Mov -2 @2   |  -4| (   0)        1: SUB @1      |   6| (   0)       [][1]
--  4: JRO LZ -2   |  -4| (   0)        2: JRO GZ -2   |   8| (   0)       [][1]
--  2: ADD @2      |  -4| (   0)        0: MOV ACC @1  |   8| (   0)       [][1]
--  2: ADD @2      |  -4| (   0)        0: Mov 8 @1    |   8| (   0)       [][1]
--  3: MOV -2 @2   |   4| (   0)        1: SUB @1      |   8| (   0)       [][1]
--  3: Mov -2 @2   |   4| (   0)        1: SUB @1      |   8| (   0)       [][1]
--  4: JRO LZ -2   |   4| (   0)        2: JRO GZ -2   |  10| (   0)       [][1]
--  5: MOV @2 @2   |   4| (   0)        0: MOV ACC @1  |  10| (   0)       [][1]
--  5: MOV @2 @2   |   4| (   0)        0: Mov 10 @1   |  10| (   0)       [][1]
--  5: Mov 10 @2   |   4| (   0)        1: SUB @1      |  10| (   0)       [][1]
--  6: MOV ACC @2  |   4| (   0)        2: JRO GZ -2   |   0| (   0)       [][1]
--  6: Mov 4 @2    |   4| (   0)        3: MOV @1 OUT  |   0| (   0)       [][1]
--  0: MOV 0 ACC   |   4| (   0)        3: Mov 4 OUT   |   0| (   0)       [][1]
--  1: SUB IN      |   0| (   0)        0: MOV ACC @1  |   0| (   0)       [][1,4]

-- %%
m <- readFile "progs/chess"

putStr m

m' = parseProgram m

run m' [] (timeout 3597) image
-- Out:
-- @m
-- A: ADD -143
-- JLZ B
-- ADD -197
-- B: ADD 161
-- MOV ACC OUT
-- SWP
-- 10: JLZ A
-- MOV 3 OUT
-- ADD 2
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████

-- %%
s <- readFile "progs/stored"

s' = parseProgram s

run s' [36,2,26,2,23,2,34,3,37,2,30,3,40,1,36,3,40,3,39,2,21,0,26,1,38,1,22,3,34,1,20,2,42,2] def image
-- Out:
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████
-- ██████████████████████████████

-- %%
e <- readFile "progs/power"

putStr e

e' = parseProgram e

run e' [0..11] def results
-- Out:
-- @powerof2
--   MOV IN  ACC
--   SAV
--   MOV 1   ACC
--
-- L:SWP
--   JEZ E
--   JLZ F
--   SUB 1
--   SWP
--   ADD ACC
--   JMP L
--
-- F:HCF
--
-- E:SWP
--   MOV ACC OUT
-- [1,2,4,8,16,32,64,128,256,512,999]
